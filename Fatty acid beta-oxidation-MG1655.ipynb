# %%
import escher
import escher.urls
import cobra
import cobra.test
import json
import os
from IPython.display import HTML
from copy import deepcopy

# %%
d = escher.urls.root_directory
print('Escher directory: %s' % d)
# Out:
# Escher directory: /Users/joanrue/anaconda/lib/python2.7/site-packages

# %% [markdown]
# ### Embed an Escher map in an IPython notebook

# %%
escher.list_available_maps()
# Out:
# [{u'map_name': u'e_coli_core.Core metabolism',
#   u'organism': u'Escherichia coli'},
#  {u'map_name': u'iJO1366.Central metabolism',
#   u'organism': u'Escherichia coli'},
#  {u'map_name': u'iJO1366.Fatty acid beta-oxidation',
#   u'organism': u'Escherichia coli'},
#  {u'map_name': u'iJO1366.Fatty acid biosynthesis (saturated)',
#   u'organism': u'Escherichia coli'},
#  {u'map_name': u'iJO1366.Nucleotide metabolism',
#   u'organism': u'Escherichia coli'},
#  {u'map_name': u'RECON1.Amino acid metabolism (partial)',
#   u'organism': u'Homo sapiens'},
#  {u'map_name': u'RECON1.Carbohydrate metabolism',
#   u'organism': u'Homo sapiens'},
#  {u'map_name': u'RECON1.Glycolysis TCA PPP', u'organism': u'Homo sapiens'},
#  {u'map_name': u'RECON1.Inositol retinol metabolism',
#   u'organism': u'Homo sapiens'},
#  {u'map_name': u'RECON1.Tryptophan metabolism', u'organism': u'Homo sapiens'},
#  {u'map_name': u'iMM904.Central carbon metabolism',
#   u'organism': u'Saccharomyces cerevisiae'}]

# %%
b = escher.Builder(map_name='iJO1366.Fatty acid beta-oxidation')
b.display_in_notebook()
# Out:
#   <!-- These are not generally used within the notebook. -->
#   <script src=""></script>
#   <script src=""></script>
#
#   <link rel="stylesheet" href=""/>
#   <link rel="stylesheet" href="//escher.github.io/builder-1.3.1.css"/>
#
#
#
#   <div style="height: 500px; width: 100%;" id="vrchteffrm"></div>
#
#   <script>
#    var map_data_vrchteffrm = [{"map_name": "iJO1366.Fatty acid beta-oxidation", "map_id": "974cac1fabddaf6e7d140e7431239870", "map_description": "\nLast Modified Thu Mar 12 2015 18:20:50 GMT-0700 (PDT)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"2076260": {"name": "Fatty-acid-CoA ligase (hexadecenoate transport via vectoral Co-A coupling)", "bigg_id": "FACOAL161t2pp", "segments": {"2604": {"to_node_id": "2078035", "from_node_id": "2078032", "b2": {"y": 4151.100439102686, "x": 624.7732216506446}, "b1": {"y": 4310.146825821436, "x": 628.4360024123633}}, "2605": {"to_node_id": "2078036", "from_node_id": "2078032", "b2": {"y": 4136.972509415186, "x": 585.4592568068946}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2606": {"to_node_id": "2078037", "from_node_id": "2078032", "b2": {"y": 4276.158544571436, "x": 653.0988442092383}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2607": {"to_node_id": "2078038", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 607.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}, "2601": {"to_node_id": "2078033", "from_node_id": "2078032", "b2": null, "b1": null}, "2602": {"to_node_id": "2078033", "from_node_id": "2078034", "b2": null, "b1": null}, "2603": {"to_node_id": "2078031", "from_node_id": "2078034", "b2": {"y": 4796.623388321436, "x": 628.4360024123633}, "b1": {"y": 4414.146825821436, "x": 628.4360024123633}}, "2610": {"to_node_id": "2078041", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 691.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}, "2608": {"to_node_id": "2078039", "from_node_id": "2078032", "b2": {"y": 4309.123388321436, "x": 654.8081337600196}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2609": {"to_node_id": "2078040", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 649.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}}, "genes": [{"bigg_id": "b1805", "name": "fadD"}, {"bigg_id": "b1701", "name": "fadK"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "atp_c"}, {"coefficient": 1.0, "bigg_id": "hdcoa_c"}, {"coefficient": -1.0, "bigg_id": "coa_c"}, {"coefficient": 1.0, "bigg_id": "amp_c"}, {"coefficient": 1.0, "bigg_id": "ppi_c"}, {"coefficient": -1.0, "bigg_id": "h_p"}, {"coefficient": -1.0, "bigg_id": "hdcea_p"}, {"coefficient": 1.0, "bigg_id": "h_c"}], "label_x": 665.7615639358008, "label_y": 4350.169775040186, "gene_reaction_rule": "b1805 or b1701"}, "2076261": {"name": "3-cis-2-trans-enoyl-CoA isomerase", "bigg_id": "CTECOAI6", "segments": {"2614": {"to_node_id": "2077867", "from_node_id": "2078044", "b2": {"y": 4844.903716651904, "x": 1034.511439568005}, "b1": {"y": 4844.903716651904, "x": 1080.011439568005}}, "2613": {"to_node_id": "2078045", "from_node_id": "2078042", "b2": {"y": 4844.903716651904, "x": 1266.139369255505}, "b1": {"y": 4844.903716651904, "x": 1184.011439568005}}, "2612": {"to_node_id": "2078043", "from_node_id": "2078044", "b2": null, "b1": null}, "2611": {"to_node_id": "2078043", "from_node_id": "2078042", "b2": null, "b1": null}}, "genes": [{"bigg_id": "b3846", "name": "fadB"}], "reversibility": true, "metabolites": [{"coefficient": 1.0, "bigg_id": "td2coa_c"}, {"coefficient": -1.0, "bigg_id": "tdecoa_c"}], "label_x": 1082.011439568005, "label_y": 4804.903716651904, "gene_reaction_rule": "b3846"}, "2076262": {"name": "Fatty-acid-CoA ligase (tetradecenoate transport via vectoral Co-A coupling)", "bigg_id": "FACOAL141t2pp", "segments": {"2617": {"to_node_id": "2078049", "from_node_id": "2078046", "b2": {"y": 4184.031646339404, "x": 1319.6160538258175}, "b1": {"y": 4290.938872901904, "x": 1314.9766495289425}}, "2616": {"to_node_id": "2078047", "from_node_id": "2078048", "b2": null, "b1": null}, "2615": {"to_node_id": "2078047", "from_node_id": "2078046", "b2": null, "b1": null}, "2621": {"to_node_id": "207805 ...

# %% [markdown]
# ### Plot FBA solutions in Escher

# %%
model = cobra.io.load_json_model( "iJO1366.json") # E coli metabolic model

FBA_Solution = model.optimize() # FBA of the original model

print('Original Growth rate: %.9f' % FBA_Solution.f)
# Out:
# Original Growth rate: 0.982371813

# %%
b = escher.Builder(map_name='iJO1366.Fatty acid beta-oxidation',
                   reaction_data=FBA_Solution.x_dict,
                   # color and size according to the absolute value
                   reaction_styles=['color', 'size', 'abs', 'text'],
                   # change the default colors
                   reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                                   {'type': 'mean', 'color': '#0000dd', 'size': 20},
                                   {'type': 'max', 'color': '#ff0000', 'size': 40}],
                   # only show the primary metabolites
                   hide_secondary_metabolites=True,
                   highlight_missing = True)
b.display_in_notebook()
#b.display_in_browser()
# Out:
#   <!-- These are not generally used within the notebook. -->
#   <script src=""></script>
#   <script src=""></script>
#
#   <link rel="stylesheet" href=""/>
#   <link rel="stylesheet" href="//escher.github.io/builder-1.3.1.css"/>
#
#
#
#   <div style="height: 500px; width: 100%;" id="qswluxlfez"></div>
#
#   <script>
#    var map_data_qswluxlfez = [{"map_name": "iJO1366.Fatty acid beta-oxidation", "map_id": "974cac1fabddaf6e7d140e7431239870", "map_description": "\nLast Modified Thu Mar 12 2015 18:20:50 GMT-0700 (PDT)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"2076260": {"name": "Fatty-acid-CoA ligase (hexadecenoate transport via vectoral Co-A coupling)", "bigg_id": "FACOAL161t2pp", "segments": {"2604": {"to_node_id": "2078035", "from_node_id": "2078032", "b2": {"y": 4151.100439102686, "x": 624.7732216506446}, "b1": {"y": 4310.146825821436, "x": 628.4360024123633}}, "2605": {"to_node_id": "2078036", "from_node_id": "2078032", "b2": {"y": 4136.972509415186, "x": 585.4592568068946}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2606": {"to_node_id": "2078037", "from_node_id": "2078032", "b2": {"y": 4276.158544571436, "x": 653.0988442092383}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2607": {"to_node_id": "2078038", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 607.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}, "2601": {"to_node_id": "2078033", "from_node_id": "2078032", "b2": null, "b1": null}, "2602": {"to_node_id": "2078033", "from_node_id": "2078034", "b2": null, "b1": null}, "2603": {"to_node_id": "2078031", "from_node_id": "2078034", "b2": {"y": 4796.623388321436, "x": 628.4360024123633}, "b1": {"y": 4414.146825821436, "x": 628.4360024123633}}, "2610": {"to_node_id": "2078041", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 691.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}, "2608": {"to_node_id": "2078039", "from_node_id": "2078032", "b2": {"y": 4309.123388321436, "x": 654.8081337600196}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2609": {"to_node_id": "2078040", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 649.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}}, "genes": [{"bigg_id": "b1805", "name": "fadD"}, {"bigg_id": "b1701", "name": "fadK"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "atp_c"}, {"coefficient": 1.0, "bigg_id": "hdcoa_c"}, {"coefficient": -1.0, "bigg_id": "coa_c"}, {"coefficient": 1.0, "bigg_id": "amp_c"}, {"coefficient": 1.0, "bigg_id": "ppi_c"}, {"coefficient": -1.0, "bigg_id": "h_p"}, {"coefficient": -1.0, "bigg_id": "hdcea_p"}, {"coefficient": 1.0, "bigg_id": "h_c"}], "label_x": 665.7615639358008, "label_y": 4350.169775040186, "gene_reaction_rule": "b1805 or b1701"}, "2076261": {"name": "3-cis-2-trans-enoyl-CoA isomerase", "bigg_id": "CTECOAI6", "segments": {"2614": {"to_node_id": "2077867", "from_node_id": "2078044", "b2": {"y": 4844.903716651904, "x": 1034.511439568005}, "b1": {"y": 4844.903716651904, "x": 1080.011439568005}}, "2613": {"to_node_id": "2078045", "from_node_id": "2078042", "b2": {"y": 4844.903716651904, "x": 1266.139369255505}, "b1": {"y": 4844.903716651904, "x": 1184.011439568005}}, "2612": {"to_node_id": "2078043", "from_node_id": "2078044", "b2": null, "b1": null}, "2611": {"to_node_id": "2078043", "from_node_id": "2078042", "b2": null, "b1": null}}, "genes": [{"bigg_id": "b3846", "name": "fadB"}], "reversibility": true, "metabolites": [{"coefficient": 1.0, "bigg_id": "td2coa_c"}, {"coefficient": -1.0, "bigg_id": "tdecoa_c"}], "label_x": 1082.011439568005, "label_y": 4804.903716651904, "gene_reaction_rule": "b3846"}, "2076262": {"name": "Fatty-acid-CoA ligase (tetradecenoate transport via vectoral Co-A coupling)", "bigg_id": "FACOAL141t2pp", "segments": {"2617": {"to_node_id": "2078049", "from_node_id": "2078046", "b2": {"y": 4184.031646339404, "x": 1319.6160538258175}, "b1": {"y": 4290.938872901904, "x": 1314.9766495289425}}, "2616": {"to_node_id": "2078047", "from_node_id": "2078048", "b2": null, "b1": null}, "2615": {"to_node_id": "2078047", "from_node_id": "2078046", "b2": null, "b1": null}, "2621": {"to_node_id": "207805 ...

# %%
# MAP EDITION
model_knockout = model.copy()
cobra.manipulation.delete_model_genes(model_knockout, ["b0693"]) #ODC - speF
cobra.manipulation.delete_model_genes(model_knockout, ["b2965"]) #ODC - speC
cobra.manipulation.delete_model_genes(model_knockout, ["b2937"]) #Agmatinase - speB.
knockout_FBA_solution = model_knockout.optimize() # FBA of the knockout

print('Knockout Growth rate: %.9f' % knockout_FBA_solution.f)
# Out:
# Knockout Growth rate: 0.982371813

# %%
#PASS THE MODEL TO A NEW BUILDER
b = escher.Builder(map_name='iJO1366.Fatty acid beta-oxidation',
                   reaction_data=knockout_FBA_solution.x_dict,
                   # color and size according to the absolute value
                   reaction_styles=['color', 'size', 'abs', 'text'],
                   # change the default colors
                   reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                                   {'type': 'mean', 'color': '#0000dd', 'size': 20},
                                   {'type': 'max', 'color': '#ff0000', 'size': 40}],
                   # only show the primary metabolites
                   hide_secondary_metabolites=True,
                   highlight_missing = True)
b.display_in_notebook()
#b.display_in_browser()
# Out:
#   <!-- These are not generally used within the notebook. -->
#   <script src=""></script>
#   <script src=""></script>
#
#   <link rel="stylesheet" href=""/>
#   <link rel="stylesheet" href="//escher.github.io/builder-1.3.1.css"/>
#
#
#
#   <div style="height: 500px; width: 100%;" id="yysrgbfoqv"></div>
#
#   <script>
#    var map_data_yysrgbfoqv = [{"map_name": "iJO1366.Fatty acid beta-oxidation", "map_id": "974cac1fabddaf6e7d140e7431239870", "map_description": "\nLast Modified Thu Mar 12 2015 18:20:50 GMT-0700 (PDT)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"2076260": {"name": "Fatty-acid-CoA ligase (hexadecenoate transport via vectoral Co-A coupling)", "bigg_id": "FACOAL161t2pp", "segments": {"2604": {"to_node_id": "2078035", "from_node_id": "2078032", "b2": {"y": 4151.100439102686, "x": 624.7732216506446}, "b1": {"y": 4310.146825821436, "x": 628.4360024123633}}, "2605": {"to_node_id": "2078036", "from_node_id": "2078032", "b2": {"y": 4136.972509415186, "x": 585.4592568068946}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2606": {"to_node_id": "2078037", "from_node_id": "2078032", "b2": {"y": 4276.158544571436, "x": 653.0988442092383}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2607": {"to_node_id": "2078038", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 607.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}, "2601": {"to_node_id": "2078033", "from_node_id": "2078032", "b2": null, "b1": null}, "2602": {"to_node_id": "2078033", "from_node_id": "2078034", "b2": null, "b1": null}, "2603": {"to_node_id": "2078031", "from_node_id": "2078034", "b2": {"y": 4796.623388321436, "x": 628.4360024123633}, "b1": {"y": 4414.146825821436, "x": 628.4360024123633}}, "2610": {"to_node_id": "2078041", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 691.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}, "2608": {"to_node_id": "2078039", "from_node_id": "2078032", "b2": {"y": 4309.123388321436, "x": 654.8081337600196}, "b1": {"y": 4306.146825821436, "x": 628.4360024123633}}, "2609": {"to_node_id": "2078040", "from_node_id": "2078034", "b2": {"y": 4437.146825821436, "x": 649.4360024123633}, "b1": {"y": 4418.146825821436, "x": 628.4360024123633}}}, "genes": [{"bigg_id": "b1805", "name": "fadD"}, {"bigg_id": "b1701", "name": "fadK"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "atp_c"}, {"coefficient": 1.0, "bigg_id": "hdcoa_c"}, {"coefficient": -1.0, "bigg_id": "coa_c"}, {"coefficient": 1.0, "bigg_id": "amp_c"}, {"coefficient": 1.0, "bigg_id": "ppi_c"}, {"coefficient": -1.0, "bigg_id": "h_p"}, {"coefficient": -1.0, "bigg_id": "hdcea_p"}, {"coefficient": 1.0, "bigg_id": "h_c"}], "label_x": 665.7615639358008, "label_y": 4350.169775040186, "gene_reaction_rule": "b1805 or b1701"}, "2076261": {"name": "3-cis-2-trans-enoyl-CoA isomerase", "bigg_id": "CTECOAI6", "segments": {"2614": {"to_node_id": "2077867", "from_node_id": "2078044", "b2": {"y": 4844.903716651904, "x": 1034.511439568005}, "b1": {"y": 4844.903716651904, "x": 1080.011439568005}}, "2613": {"to_node_id": "2078045", "from_node_id": "2078042", "b2": {"y": 4844.903716651904, "x": 1266.139369255505}, "b1": {"y": 4844.903716651904, "x": 1184.011439568005}}, "2612": {"to_node_id": "2078043", "from_node_id": "2078044", "b2": null, "b1": null}, "2611": {"to_node_id": "2078043", "from_node_id": "2078042", "b2": null, "b1": null}}, "genes": [{"bigg_id": "b3846", "name": "fadB"}], "reversibility": true, "metabolites": [{"coefficient": 1.0, "bigg_id": "td2coa_c"}, {"coefficient": -1.0, "bigg_id": "tdecoa_c"}], "label_x": 1082.011439568005, "label_y": 4804.903716651904, "gene_reaction_rule": "b3846"}, "2076262": {"name": "Fatty-acid-CoA ligase (tetradecenoate transport via vectoral Co-A coupling)", "bigg_id": "FACOAL141t2pp", "segments": {"2617": {"to_node_id": "2078049", "from_node_id": "2078046", "b2": {"y": 4184.031646339404, "x": 1319.6160538258175}, "b1": {"y": 4290.938872901904, "x": 1314.9766495289425}}, "2616": {"to_node_id": "2078047", "from_node_id": "2078048", "b2": null, "b1": null}, "2615": {"to_node_id": "2078047", "from_node_id": "2078046", "b2": null, "b1": null}, "2621": {"to_node_id": "207805 ...
